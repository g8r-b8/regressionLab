# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

data = pd.read_csv('height_data_cleaned.csv')

# %%
data
# Out:
#         FH   FR     MH   MR     CH   CG  NU
# 0    180.3  0.0  165.1  0.0  167.6  1.0   0
# 1    180.3  0.0  167.6  0.0  190.5  0.0   0
# 2    177.8  1.0  165.1  1.0  170.2  0.0   0
# 3    177.8  0.0  170.2  0.0  177.8  0.0   0
# 4    160.0  2.0  154.4  2.0  167.6  0.0   0
# ..     ...  ...    ...  ...    ...  ...  ..
# 314  181.0  0.0  162.0  0.0  179.0  0.0   0
# 315  175.0  0.0  158.0  0.0  163.0  1.0   0
# 316  178.0  0.0  162.0  0.0  160.0  1.0   0
# 317  168.0  0.0  173.0  0.0  158.0  1.0   0
# 318  168.0  2.0  161.0  2.0  173.0  1.0   1
#
# [319 rows x 7 columns]

# %%
##get the values as
#x, y, X_new

X=data[['FH','FR','MH','MR','CG','NU']]
Y=data[['CH']]

# %%
XX=X.multiply(X)

# %%
XX.columns = [str(col) + '_Squared' for col in XX.columns]

# %%
X2=pd.concat([X,XX],axis=1)

# %%
X2
# Out:
#         FH   FR     MH   MR   CG  NU  FH_x_Squared  FR_x_Squared  \
# 0    180.3  0.0  165.1  0.0  1.0   0      32508.09           0.0
# 1    180.3  0.0  167.6  0.0  0.0   0      32508.09           0.0
# 2    177.8  1.0  165.1  1.0  0.0   0      31612.84           1.0
# 3    177.8  0.0  170.2  0.0  0.0   0      31612.84           0.0
# 4    160.0  2.0  154.4  2.0  0.0   0      25600.00           4.0
# ..     ...  ...    ...  ...  ...  ..           ...           ...
# 314  181.0  0.0  162.0  0.0  0.0   0      32761.00           0.0
# 315  175.0  0.0  158.0  0.0  1.0   0      30625.00           0.0
# 316  178.0  0.0  162.0  0.0  1.0   0      31684.00           0.0
# 317  168.0  0.0  173.0  0.0  1.0   0      28224.00           0.0
# 318  168.0  2.0  161.0  2.0  1.0   1      28224.00           4.0
#
#      MH_x_Squared  MR_x_Squared  CG_x_Squared  NU_x_Squared
# 0        27258.01           0.0           1.0             0
# 1        28089.76           0.0           0.0             0
# ...

# %%
xDif=X['MH'].subtract(X['FH'])

# %%
type(xDif)
# Out:
# pandas.core.series.Series

# %%
xDist=xDif.abs()

# %%
xTallerParent=xDif.divide(xDist)

# %%
Xtemp=pd.concat([xDist,xTallerParent],axis=1)

# %%
Xtemp
# Out:
#         0    1
# 0    15.2 -1.0
# 1    12.7 -1.0
# 2    12.7 -1.0
# 3     7.6 -1.0
# 4     5.6 -1.0
# ..    ...  ...
# 314  19.0 -1.0
# 315  17.0 -1.0
# 316  16.0 -1.0
# 317   5.0  1.0
# 318   7.0 -1.0
#
# [319 rows x 2 columns]

# %%
Xtemp.columns=["Distance","TallerParent"]

# %%
Xtemp
Xtemp_S=Xtemp.multiply(Xtemp)

Xtemp_S.columns = [str(col) + '_Squared' for col in Xtemp_S.columns]

# %%
X3=pd.concat([X2,Xtemp,Xtemp_S],axis=1)

# %%
finData=pd.concat([X3,Y],axis=1)

# %%
finData.to_csv('./height_data_transformed.csv', index = False)

# %%
X4=pd.concat([X,Xtemp,Y],axis=1)

# %%
X4=X4.dropna()

# %%
X4.to_csv('./height_data_transformed_no_squares.csv', index = False)
